# %%
1. Unique Binary Search Trees
Ans. def numTrees(n):
    if n <= 0:
        return 0

    dp = [0] * (n + 1)
    dp[0] = 1

    for i in range(1, n + 1):
        for j in range(i):
            dp[i] += dp[j] * dp[i - j - 1]

    return dp[n]

2. Validate Binary Search Tree
Ans. class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def isValidBST(root):
    def isValid(node, lower=float('-inf'), upper=float('inf')):
        if not node:
            return True

        val = node.val
        if val <= lower or val >= upper:
            return False

        if not isValid(node.left, lower, val):
            return False

        if not isValid(node.right, val, upper):
            return False

        return True

    return isValid(root)

3. Recover Binary Search Tree
Ans. def recoverTree(root):
    def inorder_traversal(node):
        if not node:
            return []
        return inorder_traversal(node.left) + [node] + inorder_traversal(node.right)

    def find_swapped_nodes(nodes):
        swapped = []
        for i in range(1, len(nodes)):
            if nodes[i].val < nodes[i - 1].val:
                swapped.append(nodes[i - 1])
                swapped.append(nodes[i])
        return swapped

    def restore_bst(node, val1, val2):
        if node:
            if node.val == val1:
                node.val = val2
            elif node.val == val2:
                node.val = val1
            restore_bst(node.left, val1, val2)
            restore_bst(node.right, val1, val2)

    nodes = inorder_traversal(root)
    swapped_nodes = find_swapped_nodes(nodes)

    if len(swapped_nodes) == 2:
        restore_bst(root, swapped_nodes[0].val, swapped_nodes[1].val)


4. Covert Sorted Array to BST
Ans. class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def sortedArrayToBST(nums):
    if not nums:
        return None

    mid = len(nums) // 2
    root = TreeNode(nums[mid])
    root.left = sortedArrayToBST(nums[:mid])
    root.right = sortedArrayToBST(nums[mid + 1:])

    return root

5. Lowest Common Ancestor of a Binary Search Tree
Ans. class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def lowestCommonAncestor(root, p, q):
    if not root:
        return None

    if root.val > p.val and root.val > q.val:
        return lowestCommonAncestor(root.left, p, q)
    elif root.val < p.val and root.val < q.val:
        return lowestCommonAncestor(root.right, p, q)
    else:
        return root

6. Insert into a BST
Ans. class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def insertIntoBST(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insertIntoBST(root.left, val)
    elif val > root.val:
        root.right = insertIntoBST(root.right, val)

    return root

7. Number of Ways to Reorder Array to Get Same BST
Ans. def numWaysToReorder(nums):
    MOD = 10**9 + 7

    def combination(n, k):
        if k > n - k:
            k = n - k
        result = 1
        for i in range(k):
            result = result * (n - i) // (i + 1)
        return result

    def helper(arr):
        if len(arr) <= 2:
            return 1

        root = arr[0]
        left, right = [], []

        for num in arr[1:]:
            if num < root:
                left.append(num)
            else:
                right.append(num)

        left_ways = helper(left)
        right_ways = helper(right)
        return (combination(len(arr) - 1, len(left)) * left_ways * right_ways) % MOD

    return helper(nums) - 1  # Subtract 1 as we don't need to count the original arrangement

8. Minimum Absolute Difference in BST
Ans. class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def getMinimumDifference(root):
    def inorder_traversal(node):
        if not node:
            return []
        return inorder_traversal(node.left) + [node.val] + inorder_traversal(node.right)

    inorder_vals = inorder_traversal(root)
    min_diff = float('inf')

    for i in range(1, len(inorder_vals)):
        diff = inorder_vals[i] - inorder_vals[i - 1]
        min_diff = min(min_diff, diff)

    return min_diff
